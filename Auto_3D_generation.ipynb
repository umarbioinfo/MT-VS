# %%
# !pip install Auto3D
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting Auto3D
#   Downloading Auto3D-2.3.1-py3-none-any.whl (50.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.0/50.0 MB 2.6 MB/s eta 0:00:0000:0100:01
# Collecting Send2Trash
#   Downloading Send2Trash-1.8.3-py3-none-any.whl (18 kB)
# Requirement already satisfied: psutil in ./.local/lib/python3.10/site-packages (from Auto3D) (7.0.0)
# Requirement already satisfied: tqdm in ./.local/lib/python3.10/site-packages (from Auto3D) (4.67.1)
# Requirement already satisfied: pyyaml in /usr/lib/python3/dist-packages (from Auto3D) (5.4.1)
# Installing collected packages: Send2Trash, Auto3D
# Successfully installed Auto3D-2.3.1 Send2Trash-1.8.3

# %%
import os, sys
root = os.path.dirname(os.path.dirname(os.path.abspath("__file__")))

import Auto3D
#options is a function that takes in all user-specified parameters, then return arguments for the main function
#main function takes in the arguments from the options function, then actually runs the Auto3D modules
from Auto3D.auto3D import options, main

# %%
#Always ensure that you have the latest version
print(Auto3D.__version__)
# Out:
# 2.3.1

# %%
if __name__ == "__main__":
    path = os.path.join(root, "/media/umar/New Volume/Shareable folders/Data_TDC/data_IC50_chemberta/ML_MT/multi_target_hits_final_33_remaining.smi")  # You can specify the path to your file here
    args = options(path, k=1, use_gpu=False)   #specify the parameters for Auto3D 
    out = main(args)            #main acceps the parameters and run Auto3D
    print(out)
# Out:
# Checking input file...
# 	There are 34 SMILES in the input file /media/umar/New Volume/Shareable folders/Data_TDC/data_IC50_chemberta/ML_MT/multi_target_hits_final_33_remaining.smi.
# 	All SMILES and IDs are valid.
# Suggestions for choosing isomer_engine and optimizing_engine:
# 	Isomer engine options: RDKit and Omega.
# 	Optimizing engine options: ANI2x, ANI2xt, AIMNET or your own NNP.
# The available memory is 15 GB.
# The task will be divided into 1 jobs.
# Job1, number of inputs: 34
#
#
# Isomer generation for job1
# Enumerating cis/tran isomers for unspecified double bonds...
# Enumerating R/S isomers for unspecified atomic centers...
# Removing enantiomers...
# Enumerating conformers/rotamers, removing duplicates...
# 100%|██████████| 35/35 [06:45<00:00, 11.57s/it]
# Optimizing on job1
# Preparing for parallel optimizing... (Max optimization steps: 5000)
# Total 3D conformers: 3154
#  10%|▉         | 484/5000 [15:53:56<98:37:54, 78.63s/it]  Process Process-4:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/umar/.local/lib/python3.10/site-packages/Auto3D/auto3D.py", line 259, in logger_process
#     message = queue.get()
#   File "<string>", line 2, in get
#   File "/usr/lib/python3.10/multiprocessing/managers.py", line 818, in _callmethod
#     kind, result = conn.recv()
#   File "/usr/lib/python3.10/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/usr/lib/python3.10/multiprocessing/connection.py", line 414, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.10/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 4
#       2 path = os.path.join(root, "/media/umar/New Volume/Shareable folders/Data_TDC/data_IC50_chemberta/ML_MT/multi_target_hits_final_33_remaining.smi")  # You can specify the path to your file here
#       3 args = options(path, k=1, use_gpu=False)   #specify the parameters for Auto3D
# ----> 4 out = main(args)            #main acceps the parameters and run Auto3D
#       5 print(out)
#
# File ~/.local/lib/python3.10/site-packages/Auto3D/auto3D.py:413, in main(args)
#     411 p1.join()
#     412 for p2 in p2s:
# --> 413     p2.join()
#     415 #Combine jobs into a single sdf
#     416 data = []
#
# File /usr/lib/python3.10/multiprocessing/process.py:149, in BaseProcess.join(self, timeout)
#     147 assert self._parent_pid == os.getpid(), 'can only join a child process'
#     148 assert self._popen is not None, 'can only join a started process'
# --> 149 res = self._popen.wait(timeout)
#     150 if res is not None:
#     151     _children.discard(self)
#
# File /usr/lib/python3.10/multiprocessing/popen_fork.py:43, in Popen.wait(self, timeout)
#      41             return None
#      42     # This shouldn't block if wait() returned successfully.
# ---> 43     return self.poll(os.WNOHANG if timeout == 0.0 else 0)
#      44 return self.returncode
#
# File /usr/lib/python3.10/multiprocessing/popen_fork.py:27, in Popen.poll(self, flag)
#      25 if self.returncode is None:
#      26     try:
# ---> 27         pid, sts = os.waitpid(self.pid, flag)
#      28     except OSError:
#      29         # Child process not yet created. See #1731717
#      30         # e.errno == errno.ECHILD == 10
#      31         return None
#
# KeyboardInterrupt:
#  10%|▉         | 484/5000 [15:55:16<148:33:19, 118.42s/it]
# Process Process-6:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/umar/.local/lib/python3.10/site-packages/Auto3D/auto3D.py", line 143, in optim_rank_wrapper
#     optimizer.run()
#   File "/home/umar/.local/lib/python3.10/site-packages/Auto3D/batch_opt/batchopt.py", line 428, in run
#     optdict = ensemble_opt(model, coord_padded, numbers_padded, charges,
#   File "/home/umar/.local/lib/python3.10/site-packages/Auto3D/batch_opt/batchopt.py", line 321, in ensemble_opt
#     n_steps(state, param['opt_steps'], param['opttol'], param['patience'])
#   File "/home/umar/.local/lib/python3.10/site-packages/Auto3D/batch_opt/batchopt.py", line 242, in n_steps
#     e, f = state['nn'].forward_batched(coord, numbers,
#   File "/home/umar/.local/lib/python3.10/site-packages/Auto3D/batch_opt/batchopt.py", line 184, in forward_batched
#     _e, _f = self(coord[batch], numbers[batch], charges[batch])
#   File "/home/umar/.local/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1751, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/umar/.local/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1762, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/umar/.local/lib/python3.10/site-packages/Auto3D/batch_opt/batchopt.py", line 143, in forward
#     d = self.ani(
#   File "/home/umar/.local/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1751, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/umar/.local/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1762, in _call_impl
#     return forward_call(*args, **kwargs)
# KeyboardInterrupt
